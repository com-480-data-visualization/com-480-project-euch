# %% [markdown]
# # EDA - 120 years of Olympic history #

# %% [markdown]
# The goal of this Exploratory Data Analyis is to have a better understanding of the dataset we'll use, and to explore the data relative to our problematic direction. We'll explore the following axis:
# - Missing data
# - Global insights
# - Insights in the USA
# - Insights in Athletics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
full_data = pd.read_csv("../data/athlete_events.csv")

# %%
full_data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
# lower the features names
full_data.columns = [x.lower() for x in full_data.columns.tolist()]

# %%
full_data.shape
# Out:
# (271116, 15)

# %%
full_data.id.unique().shape
# Out:
# (135571,)

# %% [markdown]
# There are 271116 samples, each representing a result from an athlete, 15 features per samples, and there are 135571 different athletes.

# %%
full_data.year.max()
# Out:
# 2016

# %%
full_data.year.min()
# Out:
# 1896

# %% [markdown]
# We have indeed values from the years 1896 to 2016

# %%
years = np.arange(1896, 2016)

# %% [markdown]
# ## Missing values ##

# %%
full_data.notna().all(axis=0) # if there are missing values in the column
# Out:
# id         True
# name       True
# sex        True
# age       False
# height    False
# weight    False
# team       True
# noc        True
# games      True
# year       True
# season     True
# city       True
# sport      True
# event      True
# medal     False
# dtype: bool

# %% [markdown]
# The only features having missing values are age, height, weight and medals.

# %%
missing_features = full_data[['age', 'height', 'weight']].notna().all(axis=1).value_counts() #counts of rows for which we have at least a missing entry
missing_features
# Out:
# True     206165
# False     64951
# dtype: int64

# %% [markdown]
# On these features, we have around 24% percent of entries with at least one missing value. But these missing values could come from the same athletes every year. The idea is that if we know one of these features for an athlete at a given year, we could fill all the missing entries of that features for this athlete.

# %%
id_missing_features = full_data[['id', 'age', 'height', 'weight']]
id_missing_features.age = id_missing_features.age.notna()
id_missing_features.height = id_missing_features.height.notna()
id_missing_features.weight = id_missing_features.weight.notna()
id_missing_features.head()
# Out:
# /Users/sylvainlugeon/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    id   age  height  weight
# 0   1  True    True    True
# 1   2  True    True    True
# 2   3  True   False   False
# 3   4  True   False   False
# 4   5  True    True    True

# %%
id_missing_features.groupby('id').any().sum() # if we have the given feature for at least a year
# Out:
# age       129203
# height    101655
# weight    100686
# dtype: int64

# %%
id_missing_features.groupby('id').all().sum() # if we have the given feature for all year
# Out:
# age       129203
# height    101655
# weight    100686
# dtype: int64

# %% [markdown]
# We can see that the missing values in the db have already been filled, so we can't infer the age, weight or height for an athlete at a given year by looking at the entries at another year. Over all we have for the athletes:
# - 4.7% missing age
# - 25% missing height
# - 25.7% missing weight
#
# Now let's look at the distribution of the missing data according to the year and the sport.

# %%
athletes_missing_features = full_data.copy()
athletes_missing_features.drop_duplicates(subset='id', inplace=True) # drop duplicates in the athletes
athletes_missing_features['missing_features'] = athletes_missing_features[['age', 'height', 'weight']].notna().all(axis=1) #if all the features are well defined for that row
athletes_missing_features.head()
# Out:
#    id                      name sex   age  height  weight            team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    noc        games  year  season       city          sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal  missing_features
# 0       Basketball Men's Basketball   NaN              True
# 1      Judo Men's Extra-Lightweight   NaN              True
# 2           Football Men's Football   NaN             False
# 3       Tug-Of-War Men's Tug-Of-War  Gold             False
# 4  Speed Skating Women's 500 metres   NaN              True

# %%
year_missing = athletes_missing_features[~athletes_missing_features.missing_features].groupby('year').id.count() # number of rows with missing entries per year

fig, ax = plt.subplots(figsize=(12,5))

ax.bar(x=year_missing.index.values, height=year_missing.values, width=2)

ax.set_title('Number of athletes with missing features per year')
# Out:
# Text(0.5, 1.0, 'Number of athletes with missing features per year')

# %% [markdown]
# Most of the missing values come from years before 1960. We also have a hub of missing values around 1990, it could be interesting to know why... (Cold War???). We also notice some irregularities:
# - no games during both world wars
# - several games every 2 years in the beginning of the 20th century
# - winter and summer games in alternance since end of the 20th century

# %%
sport_missing = athletes_missing_features[~athletes_missing_features.missing_features].groupby('sport').id.count()
sport_missing.sort_values(ascending=False, inplace=True)
sport_missing.sum() # we verify that the sum correspond to previous result
# Out:
# 36483

# %%
sport_missing[:10]
# Out:
# sport
# Athletics           3831
# Rowing              2388
# Swimming            2187
# Football            2151
# Gymnastics          1950
# Art Competitions    1784
# Fencing             1732
# Shooting            1637
# Cycling             1594
# Boxing              1588
# Name: id, dtype: int64

# %% [markdown]
# The ten sport that have athletes with the most frequent missing values appear to be popular sports, surprisingly! But do athletes with medals also have missing values?

# %%
athletes_with_medals = athletes_missing_features[athletes_missing_features.medal.notna()]
athletes_with_medals.groupby('missing_features').id.count()
# Out:
# missing_features
# False     5644
# True     13507
# Name: id, dtype: int64

# %% [markdown]
# So when only taken into account the athletes with medals, we have 29% of athletes with at least a missing features.

# %% [markdown]
# ## Global insights

# %%
sports = full_data.groupby('sport').id.nunique().sort_values(ascending=False)

# %%
events_per_sports = full_data.groupby('sport').event.nunique()[sports.index]

# %%
fig = plt.figure(figsize=(15,12))

ax = plt.subplot(211)
sports.plot.bar()
ax.set_ylabel('atlhetes per sports')
ax.set_xlabel('')
ax.set_title("Number of unique athletes and disciplines per sports")

ax2 = plt.subplot(212)
events_per_sports.plot.bar()
ax2.set_ylabel('disciplines per sports')
ax2.set_xlabel('')

fig.tight_layout(pad=0.4)

plt.show()

# %% [markdown]
# Above are the number of athlete and the number of disciplines per sports, there are 66 differents sports, most popular is by Athletics. In general, a popular sport will tend to have more disciplines, but there are some exceptions (e.g Football)

# %%
athletes_countries = full_data.groupby('noc').count() # athletes and medals (count ignore nan) per countries
athletes_countries.sort_values(by='id', ascending=False, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(16,5))

nb_displayed = 50

labels = athletes_countries.index.values[:nb_displayed]
no_medals = athletes_countries.id.values[:nb_displayed] - athletes_countries.medal.values[:nb_displayed]
medals = athletes_countries.medal.values[:nb_displayed]

ax.bar(labels, no_medals)
ax.bar(labels, medals, bottom=no_medals)

plt.xticks(rotation=90)

ax.set_title('Number of athletes and medals (orange) per countries')


plt.show()

# %% [markdown]
# Above is the total number of athletes and number of medals for each countries.

# %%
athletes_year_summer = full_data[full_data.season == 'Summer'].groupby('year').id.count()
athletes_year_winter = full_data[full_data.season == 'Winter'].groupby('year').id.count()

# %%
fig, ax = plt.subplots(figsize=(10,5))
athletes_year_summer.plot.line(label='Summer')
athletes_year_winter.plot.line(label='Winter')

ax.scatter(x=athletes_year_summer.index.values, y=athletes_year_summer.values)
ax.scatter(x=athletes_year_winter.index.values, y=athletes_year_winter.values)


ax.set_title('Number of athletes per year')
ax.legend()
plt.show()

# %% [markdown]
# The number of athlete is globally inceasing. But we remark that there is a drop in the number of athletes for certain years. Lines with interpolation are used here (and in some following plots) for a better visualization of the trend.

# %% [markdown]
# ## A closer look at the USA

# %% [markdown]
# The goal of this section is to have a look at the evolution within the USA athletes.

# %%
usa = full_data.copy()
usa = usa[(usa.noc == 'USA') & (usa.season == 'Summer')]

# %%
usa_athletes_year = usa.groupby('year')[['id', 'medal']].count()

# %%
fig, ax = plt.subplots(figsize=(10,5))

usa_athletes_year.id.plot.line(label='Athletes')
usa_athletes_year.medal.plot.line(label='Medals')

ax.scatter(x=usa_athletes_year.id.index.values, y=usa_athletes_year.id.values)

ax.scatter(x=usa_athletes_year.medal.index.values, y=usa_athletes_year.medal.values)

ax.set_title('Athletes and medals per year (only summer games) for the USA')
ax.legend()
plt.show()

# %% [markdown]
# Huge peak in 1904! Otherwise, the number of athletes and medals is globally increasing. The ratio medals/athletes seems to be more or less constant.

# %%
usa_athletes_year['medals_ratio'] = usa_athletes_year.apply(lambda row : row.medal / row.id, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10,5))

usa_athletes_year.medals_ratio.plot.line()

ax.scatter(x=usa_athletes_year.medals_ratio.index.values, y=usa_athletes_year.medals_ratio.values)

ax.set_title('Medals/Athletes ratio (only summer games) for the USA')
ax.set_ylim(0,1)
plt.show()

# %% [markdown]
# Since 1950, the ratio remains pretty constant (except for the year 1984)

# %% [markdown]
# ## Closer look at Athletics

# %%
athletics = full_data.copy()
athletics = athletics[athletics.sport == 'Athletics']

# %%
events_athletics = athletics.groupby('event').id.count().sort_values(ascending=False)
events_athletics
# Out:
# event
# Athletics Men's Marathon                     2093
# Athletics Men's 100 metres                   1936
# Athletics Men's 4 x 100 metres Relay         1910
# Athletics Men's 4 x 400 metres Relay         1749
# Athletics Men's 200 metres                   1495
#                                              ...
# Athletics Men's 4,000 metres Steeplechase       8
# Athletics Men's 2,590 metres Steeplechase       7
# Athletics Men's Shot Put, Both Hands            7
# Athletics Men's All-Around Championship         7
# Athletics Men's 2,500 metres Steeplechase       6
# Name: id, Length: 83, dtype: int64

# %% [markdown]
# There are 83 different discipline in 'Athletics'. Some are very popular, some less.

# %%
athletics.groupby('id').event.count().sort_values(ascending=False) #number of event for each athlete
# Out:
# id
# 68647     22
# 90007     19
# 109597    15
# 89220     12
# 87390     12
#           ..
# 56414      1
# 56409      1
# 56402      1
# 56393      1
# 43269      1
# Name: event, Length: 22071, dtype: int64

# %% [markdown]
# And some athletes participate at several events!

# %%
medals_athletics = athletics.groupby('noc').medal.count().sort_values(ascending=False)

# %%
medals_athletics[:10]
# Out:
# noc
# USA    1080
# GBR     338
# URS     242
# JAM     156
# GER     154
# GDR     140
# FIN     138
# SWE     128
# FRA     116
# RUS     103
# Name: medal, dtype: int64

# %% [markdown]
# The ten countries that have won the most medals in athletics. USA is by far at the head, following by the UK and Russia.

# %%
athletics_year = athletics.groupby('year').id.count()

# %%
fig, ax = plt.subplots(figsize=(10,5))

athletics_year.plot.line()

ax.scatter(x=athletics_year.index.values, y=athletics_year.values)


ax.set_title('Number of athletes in Athletics')
plt.show()

# %% [markdown]
# The number of athletes competiting in Athletics is overall increasing, despite it is one the the oldest sports. Now we'd like to investigate the evolution of the physical characteristics (age, height, weight) througout the years. First we'll compute the mean through all the athletes competing in Athletics, and we'll then compute the mean but only for the disciplines 'Men's 4 x 100 metres Relay' and 'Men's Marathon'.

# %%
athletics_unique = athletics.drop_duplicates(subset='id') # we drop the duplicates of the athletes that maybe have competiting in several disciplines

# %%
athletics_physic = athletics_unique[athletics_unique.sport == "Athletics"].groupby('year')[['age', 'height', 'weight']].mean()

# %%
athletics_physic.head()
# Out:
#             age      height     weight
# year
# 1896  22.588235  174.857143  72.230769
# 1900  22.836735  175.380952  71.857143
# 1904  23.636364  177.526316  71.388889
# 1906  23.820755  178.073171  72.763158
# 1908  23.358491  177.000000  71.472727

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.subplot(311)

athletics_physic.age.plot.line()
ax.scatter(x=athletics_physic.index, y=athletics_physic.age.values)

ax.set_ylabel('age')
ax.set_xlabel('')
ax.set_title("Evolution of the mean age, height and weight in Athletics")

ax2 = plt.subplot(312)

athletics_physic.height.plot.line(color='orange')
ax2.scatter(x=athletics_physic.index, y=athletics_physic.height.values, color='orange')

ax2.set_ylabel('height')
ax2.set_xlabel('')

ax3 = plt.subplot(313)

athletics_physic.weight.plot.line(color='green')
ax3.scatter(x=athletics_physic.index, y=athletics_physic.weight.values, color='green')

ax3.set_ylabel('weight')
ax3.set_xlabel('')

plt.show()

# %% [markdown]
# Respective to all the athlete comptiting in athletics, we can see the trend that the height and weight are decreasing throughout the years (surprisingly) while the age is increasing.

# %%
athletics_physic_relay = athleticsathletics[athletics_unique.event == "Athletics Men's 4 x 100 metres Relay"].groupby('year')[['age', 'height', 'weight']].mean()

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.subplot(311)

athletics_physic_relay.age.plot.line()
ax.scatter(x=athletics_physic_relay.index, y=athletics_physic_relay.age.values)

ax.set_ylabel('age')
ax.set_xlabel('')
ax.set_title("Evolution of the mean age, height and weight in the Men's 4 x 100 metres Relay")

ax2 = plt.subplot(312)

athletics_physic_relay.height.plot.line(color='orange')
ax2.scatter(x=athletics_physic_relay.index, y=athletics_physic_relay.height.values, color='orange')

ax2.set_ylabel('height')
ax2.set_xlabel('')

ax3 = plt.subplot(313)

athletics_physic_relay.weight.plot.line(color='green')
ax3.scatter(x=athletics_physic_relay.index, y=athletics_physic_relay.weight.values, color='green')

ax3.set_ylabel('weight')
ax3.set_xlabel('')

plt.show()

# %% [markdown]
# Respective to the athletes competing in the Men's 4 x 100 metres Relay, age, height and weight seem to have increased in the recent years. This is not the same trend as the mean over all the Athletics.

# %%
athletics_physic_mara = athletics[athletics.event == "Athletics Men's Marathon"].groupby('year')[['age', 'height', 'weight']].mean()

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.subplot(311)

athletics_physic_mara.age.plot.line()
ax.scatter(x=athletics_physic_mara.index, y=athletics_physic_mara.age.values)


ax.set_ylabel('age')
ax.set_xlabel('')
ax.set_title("Evolution of the mean age, height and weight in the Men's 4 x 100 metres Relay")

ax2 = plt.subplot(312)

athletics_physic_mara.height.plot.line(color='orange')
ax2.scatter(x=athletics_physic_mara.index, y=athletics_physic_mara.height.values, color='orange')

ax2.set_ylabel('height')
ax2.set_xlabel('')

ax3 = plt.subplot(313)

athletics_physic_mara.weight.plot.line(color='green')
ax3.scatter(x=athletics_physic_mara.index, y=athletics_physic_mara.weight.values, color='green')

ax3.set_ylabel('weight')
ax3.set_xlabel('')

plt.show()

# %% [markdown]
# In marathon, the weight hasn't change much and has always been the smallest possible. But there age and height have increased over the years.
